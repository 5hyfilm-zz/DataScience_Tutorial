# %%
import pandas as pd

# %%
data = pd.read_csv('FWCR_all_data-Sheet1.csv')

# %% [markdown]
# # See The Head Of Data

# %%
data.head(20)
# Out:
#          date  temperature  humidity  windspeed  rainchance  people  chicken  \
# 0    1/6/2019         36.0      65.0       21.0        30.0   108.0     12.0
# 1    2/6/2019         36.0      70.0       15.0        70.0   123.0     12.7
# 2    3/6/2019         36.0      66.0       17.0        30.0    77.0     10.0
# 3    4/6/2019         36.0      72.0       10.0        30.0    80.0     10.0
# 4    5/6/2019         35.0      69.0       15.0        80.0    74.0      9.7
# 5    6/6/2019         36.0      68.0       17.0        70.0    87.0     10.1
# 6    7/6/2019         34.0      66.0       18.0        60.0    97.0     11.4
# 7    8/6/2019         34.0      66.0       19.0        60.0   112.0     11.8
# 8    9/6/2019         34.0      67.0       13.0        80.0   135.0     13.1
# 9   10/6/2019         34.0      70.0       13.0        90.0    68.0      6.3
# 10  11/6/2019         30.0      70.0       13.0        50.0    76.0      9.7
# ...

# %%
data.shape
# Out:
# (95, 10)

# %%
data.tail()
# Out:
#          date  temperature  humidity  windspeed  rainchance      people  \
# 90  30/8/2019         32.0      75.0        4.0        80.0   53.000000
# 91  31/8/2019         32.0      72.0        4.0        30.0  101.000000
# 92        NaN          NaN       NaN        NaN         NaN         NaN
# 93    AVERAGE          NaN       NaN        NaN         NaN   93.119565
# 94   1 person          NaN       NaN        NaN         NaN    1.000000
#
#       chicken       pork      fish  vegetable
# 90   6.000000   8.300000  6.100000   3.900000
# 91  11.000000  12.600000  8.000000   7.500000
# 92        NaN        NaN       NaN        NaN
# 93   9.690217  11.600000  7.602174   6.622826
# 94   0.104062   0.124571  0.081639   0.071122

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 95 entries, 0 to 94
# Data columns (total 10 columns):
# date           94 non-null object
# temperature    92 non-null float64
# humidity       92 non-null float64
# windspeed      92 non-null float64
# rainchance     92 non-null float64
# people         94 non-null float64
# chicken        94 non-null float64
# pork           94 non-null float64
# fish           94 non-null float64
# vegetable      94 non-null float64
# dtypes: float64(9), object(1)
# memory usage: 7.5+ KB

# %% [markdown]
# # See Random Of The Sample

# %%
data.sample(5)
# Out:
#          date  temperature  humidity  windspeed  rainchance  people  chicken  \
# 2    3/6/2019         36.0      66.0       17.0        30.0    77.0     10.0
# 80  20/8/2019         33.0      76.0       11.0        40.0    79.0      6.9
# 55  26/7/2019         33.0      71.0       10.0        70.0    72.0      7.0
# 28  29/6/2019         33.0      68.0       17.0        60.0   128.0     11.8
# 14  15/6/2019         35.0      71.0       10.0        70.0   130.0     13.0
#
#     pork  fish  vegetable
# 2   12.3   6.4        6.3
# 80   9.6   8.8        5.2
# 55   8.8   8.5        5.4
# 28  15.0   8.8        7.5
# 14  15.0   8.0        7.5

# %%
data.mean()
# Out:
# temperature    33.402174
# humidity       73.663043
# windspeed      12.423913
# rainchance     55.543478
# people         92.139570
# chicken         9.588237
# pork           11.477921
# fish            7.522168
# vegetable       6.553127
# dtype: float64

# %%
data.manufacture
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-25-adb1438f8cd5> in <module>
# ----> 1 data.manufacture
#
# /Library/Frameworks/Python.framework/Versions/3.7/lib/python3.7/site-packages/pandas/core/generic.py in __getattr__(self, name)
#    5177             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5178                 return self[name]
# -> 5179             return object.__getattribute__(self, name)
#    5180
#    5181     def __setattr__(self, name, value):
#
# AttributeError: 'DataFrame' object has no attribute 'manufacture'
